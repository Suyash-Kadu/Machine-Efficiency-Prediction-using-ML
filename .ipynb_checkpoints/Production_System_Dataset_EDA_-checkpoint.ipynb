# %% [markdown]
# ## Objectives

# %% [markdown]
# Leverage Python, machine learning, and industrial sensor data to develop a predictive model that quantifies machine efficiency. The goal is to analyze the relationship between mechanical variables—such as temperature, vibration, and pressure to optimize production status and reduce error rates.

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# The manufacturing dataset contains raw sensor telemetry characterized by missing values, inconsistent scales, and non-linear distributions. By removing temporal dependencies, this project focuses on a cross-sectional analysis of machine states to:
#
# ##### Data Cleaning & Transformation:
# Handle null values and normalize diverse units (e.g., Pressure in Pa vs. Temperature in °C) to ensure feature parity.
# ##### Exploratory Analysis:
# Uncover how physical stressors like vibration intensity and power consumption directly impact the efficiency_score regardless of when they occur.
# ##### Predictive Modeling:
# Build a robust classification or regression system to identify "Inefficient" states and provide data-driven insights for proactive equipment optimization.

# %% [markdown]
# ## Dataset Information

# %% [markdown]
# timestamp: Real-time data capture in minute-level intervals.
# machine_id: Unique identifier for each machine.
# machine_type: Type of production equipment.
# temperature: Machine temperature (°C).
# vibration_level: Vibration intensity indicating potential wear or misalignment.
# power_consumption: Energy usage in kilowatts (kW).
# pressure: System pressure in pascals (Pa).
# material_flow_rate: Speed of material movement through the system.
# cycle_time: Duration of one production cycle (seconds).
# error_rate: Proportion of defective products in the cycle.
# downtime: Machine inactivity time (minutes).
# maintenance_flag: Indicates whether maintenance is required (0 = No, 1 = Yes).
# efficiency_score: Overall production efficiency (0 to 100).
# production_status: Binary indicator for production efficiency (0 = Inefficient, 1 = Efficient).

# %% [markdown]
# ## Import Libraries

# %%
# Data Manupulation Libraries
import pandas as pd
import numpy as np

# Data Visulization Libraries
import matplotlib.pyplot as plt
import seaborn as sns

# Feature Extraction Libraries
from sklearn.preprocessing import LabelEncoder, OrdinalEncoder, OneHotEncoder, MinMaxScaler, StandardScaler
from sklearn.model_selection import train_test_split

# 
from statsmodels.stats.outliers_influence import variance_inflation_factor

# Machine Learning Libraries
from sklearn.linear_model import LinearRegression, Lasso, Ridge
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor, plot_tree
from sklearn.ensemble import RandomForestRegressor, AdaBoostRegressor, GradientBoostingRegressor
# !pip install --upgrade xgboost scikit-learn
from xgboost import XGBRegressor
from sklearn.svm import SVR

# Hyperparameter Tuning Libraries
from sklearn.model_selection import GridSearchCV

# Model Evluation Libraries
from scipy.stats import shapiro, normaltest, kstest
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Pickel file Libraries
import pickle
# Out:
# Requirement already satisfied: xgboost in C:\ProgramData\anaconda3\Lib\site-packages (3.2.0)
# Requirement already satisfied: scikit-learn in C:\ProgramData\anaconda3\Lib\site-packages (1.8.0)
# Requirement already satisfied: numpy in C:\ProgramData\anaconda3\Lib\site-packages (from xgboost) (2.1.3)
# Requirement already satisfied: scipy in C:\ProgramData\anaconda3\Lib\site-packages (from xgboost) (1.15.3)
# Requirement already satisfied: joblib>=1.3.0 in C:\ProgramData\anaconda3\Lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.2.0 in C:\ProgramData\anaconda3\Lib\site-packages (from scikit-learn) (3.5.0)

# %% [markdown]
# ## Import Dataset

# %%
df = pd.read_csv("C:/Users/Suyash Kadu/Desktop/CODING/NOTES/Machine Learning/Production System Dataset.csv")
df
# Out:
#                 timestamp machine_id machine_type  temperature  \
# 0     2025-03-10 08:00:00       M003       Welder    78.302879
# 1     2025-03-10 08:01:00       M004     Conveyor    80.877076
# 2     2025-03-10 08:02:00       M001        Drill    71.315418
# 3     2025-03-10 08:03:00       M003     Conveyor    76.496198
# 4     2025-03-10 08:04:00       M003          CNC    73.612202
# ...                   ...        ...          ...          ...
# 2455  2025-03-12 00:55:00       M001     Conveyor    80.585617
# 2456  2025-03-12 00:56:00       M003        Drill    78.171483
# 2457  2025-03-12 00:57:00       M003       Welder    78.782847
# 2458  2025-03-12 00:58:00       M001        Drill    77.939129
# 2459  2025-03-12 00:59:00       M002          CNC    89.120143
#
#       vibration_level  power_consumption  pressure  material_flow_rate  \
# 0            2.043751          23.059855  5.088076           20.011026
# 1            2.175590          16.012814  5.412956           18.375739
# 2            2.154465          15.759164  5.769405           17.112107
# 3            2.245978          16.490268  4.618784           21.090684
# 4            2.097302          18.064286  5.431250           20.868592
# ...               ...                ...       ...                 ...
# 2455         1.744735          14.463169  5.034138           20.826884
# 2456         2.732367          19.990335  4.971981           18.291071
# 2457         2.131138          19.874735  5.290168           22.551457
# 2458         2.027617          19.660323  4.924919           22.706616
# 2459         7.541178          23.514487  4.584506           19.649181
#
#       cycle_time  error_rate  downtime  maintenance_flag  efficiency_score  \
# 0     118.146510    0.883246         0                 0         11.675410
# 1     123.062058    0.777073        38                 0          3.292706
# 2     122.754064    0.757374        37                 0          5.762582
# 3     118.990270    0.796481        39                 0          0.851911
# 4     113.749872    0.813361         0                 0         18.663902
# ...          ...         ...       ...               ...               ...
# 2455  113.009590    0.652834         0                 0         34.716573
# 2456  132.987186    0.988201         0                 0          1.179945
# 2457  114.350925    0.847650         0                 0         15.234984
# 2458  117.406875    0.807874         0                 0         19.212551
# 2459  122.585002    1.000000         0                 1          0.000000
#
#       production_status
# 0                     0
# 1                     0
# 2                     0
# 3                     0
# 4                     0
# ...                 ...
# 2455                  0
# 2456                  0
# 2457                  0
# 2458                  0
# 2459                  0
#
# [2460 rows x 14 columns]

# %%
df.shape
# Out:
# (2460, 14)

# %%
df.size
# Out:
# 34440

# %%
df.describe()
# Out:
#        temperature  vibration_level  power_consumption     pressure  \
# count  2411.000000      2404.000000        2405.000000  2460.000000
# mean     77.938602         2.230957          18.422577     4.993933
# std       3.944714         1.117706           2.669908     0.391494
# min      66.136665         1.048872          10.326689     3.431040
# 25%      75.240313         1.806224          16.741559     4.732438
# 50%      77.734034         2.005956          18.159299     4.992426
# 75%      80.165885         2.230489          19.699169     5.251234
# max      94.569177         9.109769          34.368410     6.351107
#
#        material_flow_rate   cycle_time   error_rate     downtime  \
# count         2460.000000  2460.000000  2460.000000  2460.000000
# mean            20.032925   120.071115     0.794854    12.313008
# std              1.511022     5.057995     0.085257    18.408838
# min             15.376157   101.823999     0.540933     0.000000
# 25%             19.017601   116.624522     0.735993     0.000000
# 50%             20.031692   120.089570     0.789355     0.000000
# 75%             21.050319   123.567379     0.842145    36.000000
# max             25.143366   142.395421     1.000000    50.000000
#
#        maintenance_flag  efficiency_score  production_status
# count       2460.000000       2460.000000             2460.0
# mean           0.059350         15.577832                0.0
# std            0.236326         10.763130                0.0
# min            0.000000          0.000000                0.0
# 25%            0.000000          5.760614                0.0
# 50%            0.000000         17.017636                0.0
# 75%            0.000000         23.980193                0.0
# max            1.000000         45.906702                0.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2460 entries, 0 to 2459
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   timestamp           2460 non-null   object
#  1   machine_id          2460 non-null   object
#  2   machine_type        2460 non-null   object
#  3   temperature         2411 non-null   float64
#  4   vibration_level     2404 non-null   float64
#  5   power_consumption   2405 non-null   float64
#  6   pressure            2460 non-null   float64
#  7   material_flow_rate  2460 non-null   float64
#  8   cycle_time          2460 non-null   float64
#  9   error_rate          2460 non-null   float64
#  10  downtime            2460 non-null   int64
#  11  maintenance_flag    2460 non-null   int64
#  12  efficiency_score    2460 non-null   float64
#  13  production_status   2460 non-null   int64
# dtypes: float64(8), int64(3), object(3)
# memory usage: 269.2+ KB

# %%
df.isna().sum()
# Out:
# timestamp              0
# machine_id             0
# machine_type           0
# temperature           49
# vibration_level       56
# power_consumption     55
# pressure               0
# material_flow_rate     0
# cycle_time             0
# error_rate             0
# downtime               0
# maintenance_flag       0
# efficiency_score       0
# production_status      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## EDA

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2460 entries, 0 to 2459
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   timestamp           2460 non-null   object
#  1   machine_id          2460 non-null   object
#  2   machine_type        2460 non-null   object
#  3   temperature         2411 non-null   float64
#  4   vibration_level     2404 non-null   float64
#  5   power_consumption   2405 non-null   float64
#  6   pressure            2460 non-null   float64
#  7   material_flow_rate  2460 non-null   float64
#  8   cycle_time          2460 non-null   float64
#  9   error_rate          2460 non-null   float64
#  10  downtime            2460 non-null   int64
#  11  maintenance_flag    2460 non-null   int64
#  12  efficiency_score    2460 non-null   float64
#  13  production_status   2460 non-null   int64
# dtypes: float64(8), int64(3), object(3)
# memory usage: 269.2+ KB

# %%
df.isna().sum()
# Out:
# timestamp              0
# machine_id             0
# machine_type           0
# temperature           49
# vibration_level       56
# power_consumption     55
# pressure               0
# material_flow_rate     0
# cycle_time             0
# error_rate             0
# downtime               0
# maintenance_flag       0
# efficiency_score       0
# production_status      0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isna().sum()
# Out:
# timestamp             0
# machine_id            0
# machine_type          0
# temperature           0
# vibration_level       0
# power_consumption     0
# pressure              0
# material_flow_rate    0
# cycle_time            0
# error_rate            0
# downtime              0
# maintenance_flag      0
# efficiency_score      0
# production_status     0
# dtype: int64

# %%
df.shape
# Out:
# (2303, 14)

# %%
df["machine_type"].duplicated().sum()
# Out:
# np.int64(2299)

# %%
df["machine_id"].duplicated().sum()
# Out:
# np.int64(2299)

# %%
df
# Out:
#                 timestamp machine_id machine_type  temperature  \
# 0     2025-03-10 08:00:00       M003       Welder    78.302879
# 1     2025-03-10 08:01:00       M004     Conveyor    80.877076
# 2     2025-03-10 08:02:00       M001        Drill    71.315418
# 3     2025-03-10 08:03:00       M003     Conveyor    76.496198
# 4     2025-03-10 08:04:00       M003          CNC    73.612202
# ...                   ...        ...          ...          ...
# 2455  2025-03-12 00:55:00       M001     Conveyor    80.585617
# 2456  2025-03-12 00:56:00       M003        Drill    78.171483
# 2457  2025-03-12 00:57:00       M003       Welder    78.782847
# 2458  2025-03-12 00:58:00       M001        Drill    77.939129
# 2459  2025-03-12 00:59:00       M002          CNC    89.120143
#
#       vibration_level  power_consumption  pressure  material_flow_rate  \
# 0            2.043751          23.059855  5.088076           20.011026
# 1            2.175590          16.012814  5.412956           18.375739
# 2            2.154465          15.759164  5.769405           17.112107
# 3            2.245978          16.490268  4.618784           21.090684
# 4            2.097302          18.064286  5.431250           20.868592
# ...               ...                ...       ...                 ...
# 2455         1.744735          14.463169  5.034138           20.826884
# 2456         2.732367          19.990335  4.971981           18.291071
# 2457         2.131138          19.874735  5.290168           22.551457
# 2458         2.027617          19.660323  4.924919           22.706616
# 2459         7.541178          23.514487  4.584506           19.649181
#
#       cycle_time  error_rate  downtime  maintenance_flag  efficiency_score  \
# 0     118.146510    0.883246         0                 0         11.675410
# 1     123.062058    0.777073        38                 0          3.292706
# 2     122.754064    0.757374        37                 0          5.762582
# 3     118.990270    0.796481        39                 0          0.851911
# 4     113.749872    0.813361         0                 0         18.663902
# ...          ...         ...       ...               ...               ...
# 2455  113.009590    0.652834         0                 0         34.716573
# 2456  132.987186    0.988201         0                 0          1.179945
# 2457  114.350925    0.847650         0                 0         15.234984
# 2458  117.406875    0.807874         0                 0         19.212551
# 2459  122.585002    1.000000         0                 1          0.000000
#
#       production_status
# 0                     0
# 1                     0
# 2                     0
# 3                     0
# 4                     0
# ...                 ...
# 2455                  0
# 2456                  0
# 2457                  0
# 2458                  0
# 2459                  0
#
# [2303 rows x 14 columns]

# %% [markdown]
# ## Column Data
#
# #### Continuous Data = temperature, vibration_level, power_consumption, pressure, material_flow_rate, cycle_time, error_rate, downtime, efficiency_score
#
# #### Categorical Data = machine_id, machine_type, maintenance_flag, production_status

# %% [markdown]
# ## Univariate Analysis

# %%
def Univariate_Continuous_Data_Analysis(col):
    print("---"*45)

    a = pd.DataFrame({
        "Mean": [df[col].mean()],
        "Median": [df[col].median()],
        "Variance": [df[col].var()],
        "Standard Deviation": [df[col].std()],
        "Range": [(df[col].max()) - (df[col].min())]
    })

    print(a)
    print("---"*45)

    sns.histplot(df[col], kde = True, color="orange")
    plt.show()

# %%
for i in ("temperature", "vibration_level", "power_consumption", "pressure", 
          "material_flow_rate", "cycle_time", "error_rate", "downtime", "efficiency_score"):
    print(f"---------- Column Name: {i.upper()} ----------")
    print("")
    Univariate_Continuous_Data_Analysis(i)
# Out:
# ---------- Column Name: TEMPERATURE ----------
#
# ---------------------------------------------------------------------------------------------------------------------------------------
#         Mean     Median   Variance  Standard Deviation     Range
# 0  77.920389  77.723363  15.411875            3.925796  28.41586
# ---------------------------------------------------------------------------------------------------------------------------------------
# ---------- Column Name: VIBRATION_LEVEL ----------
#
# ---------------------------------------------------------------------------------------------------------------------------------------
#        Mean    Median  Variance  Standard Deviation     Range
# 0  2.226426  2.004705  1.229406            1.108786  8.060897
# ---------------------------------------------------------------------------------------------------------------------------------------
# ---------- Column Name: POWER_CONSUMPTION ----------
#
# ---------------------------------------------------------------------------------------------------------------------------------------
#         Mean     Median  Variance  Standard Deviation     Range
# 0  18.413512  18.156015  7.005049            2.646705  23.74514
# ---------------------------------------------------------------------------------------------------------------------------------------
# ---------- Column Name: PRESSURE ----------
#
# ---------------------------------------------------------------------------------------------------------------------------------------
#       Mean    Median  Variance  Standard Deviation     Range
# 0  4.99431  4.992746  0.153511            0.391805  2.920067
# ---------------------------------------------------------------------------------------------------------------------------------------
# ---------- Column Name: MATERIAL_FLOW_RATE ----------
#
# ---------------------------------------------------------------------------------------------------------------------------------------
#         Mean     Median  Variance  Standard Deviation     Range
# 0  20.025513  20.030041  2.301835             1.51718  9.767209
# ---------------------------------------------------------------------------------------------------------------------------------------
# ---------- Column Name: CYCLE_TIME ----------
#
# ---------------------------------------------------------------------------------------------------------------------------------------
#          Mean      Median   Variance  Standard Deviation      Range
# 0  120.048745  120.085344  25.720387            5.071527  40.571422
# ---------------------------------------------------------------------------------------------------------------------------------------
# ---------- Column Name: ERROR_RATE ----------
#
# ---------------------------------------------------------------------------------------------------------------------------------------
#        Mean    Median  Variance  Standard Deviation     Range
# 0  0.794587  0.788974  0.007196             0.08483  0.459067
# ---------------------------------------------------------------------------------------------------------------------------------------
# ---------- Column Name: DOWNTIME ----------
#
# ---------------------------------------------------------------------------------------------------------------------------------------
#         Mean  Median    Variance  Standard Deviation  Range
# 0  12.411637     0.0  339.975573           18.438427     50
# ---------------------------------------------------------------------------------------------------------------------------------------
# ---------- Column Name: EFFICIENCY_SCORE ----------
#
# ---------------------------------------------------------------------------------------------------------------------------------------
#         Mean     Median    Variance  Standard Deviation      Range
# 0  15.542868  16.967619  115.899976           10.765685  45.906702
# ---------------------------------------------------------------------------------------------------------------------------------------

# %%
def Univariate_categorical_Data_Analysis(col):
    a = pd.DataFrame({
        "Unique Values Count": [df[col].nunique()],
        "Value Count": [df[col].value_counts().sum()]
    })
    
    print(a)
    print("---"*45)

    sns.countplot(x=df[col], color="skyblue")
    plt.show()

# %%
for i in ("machine_id", "machine_type", "maintenance_flag", "production_status"):
    print(f"---------- Column name: {i.upper()} ----------")
    Univariate_categorical_Data_Analysis(i)
# Out:
# ---------- Column name: MACHINE_ID ----------
#    Unique Values Count  Value Count
# 0                    4         2303
# ---------------------------------------------------------------------------------------------------------------------------------------
# ---------- Column name: MACHINE_TYPE ----------
#    Unique Values Count  Value Count
# 0                    4         2303
# ---------------------------------------------------------------------------------------------------------------------------------------
# ---------- Column name: MAINTENANCE_FLAG ----------
#    Unique Values Count  Value Count
# 0                    2         2303
# ---------------------------------------------------------------------------------------------------------------------------------------
# ---------- Column name: PRODUCTION_STATUS ----------
#    Unique Values Count  Value Count
# 0                    1         2303
# ---------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Bivariate Analysis

# %%
def bivariate_continuous_analysis(col):
    sns.scatterplot(x=df[col], y=df["efficiency_score"], hue=df["machine_type"], color="black")
    plt.show()

def bivariate_categorical_analysis(col1):
    sns.countplot(x=df[col1], hue=df["machine_type"])
    plt.show()

# %%
for i in ("temperature", "vibration_level", "power_consumption", "pressure", 
          "material_flow_rate", "cycle_time", "error_rate", "downtime"):
    print(f"-------- Doing comparison of {i.upper()} and Efficiency_Score using scatter plot --------")
    bivariate_continuous_analysis(i)
# Out:
# -------- Doing comparison of TEMPERATURE and Efficiency_Score using scatter plot --------
# -------- Doing comparison of VIBRATION_LEVEL and Efficiency_Score using scatter plot --------
# -------- Doing comparison of POWER_CONSUMPTION and Efficiency_Score using scatter plot --------
# -------- Doing comparison of PRESSURE and Efficiency_Score using scatter plot --------
# -------- Doing comparison of MATERIAL_FLOW_RATE and Efficiency_Score using scatter plot --------
# -------- Doing comparison of CYCLE_TIME and Efficiency_Score using scatter plot --------
# -------- Doing comparison of ERROR_RATE and Efficiency_Score using scatter plot --------
# -------- Doing comparison of DOWNTIME and Efficiency_Score using scatter plot --------

# %%
for i in ("machine_id", "maintenance_flag", "production_status"):
    print("")
    print(f"-------- Doing comparison of {i.upper()} and Machine type using Count plot --------")
    print("")
    bivariate_categorical_analysis(i)
# Out:
# -------- Doing comparison of MACHINE_ID and Machine type using Count plot --------
# -------- Doing comparison of MAINTENANCE_FLAG and Machine type using Count plot --------
# -------- Doing comparison of PRODUCTION_STATUS and Machine type using Count plot --------

# %% [markdown]
# ## Outliers

# %%
def checking_and_handling_of_outliers(col):
    print(f"Checking and Handling of Outliers for {col}")
    sns.boxplot(df[col], color = "pink")
    plt.show()

    q1 = df[col].quantile(0.25)
    q3 = df[col].quantile(0.75)

    iqr = q3-q1

    lowertail = q1-1.5*iqr
    uppertail = q3+1.5*iqr

    print("-"*60)
    print(f"LowerTail = {lowertail}")
    print(f"UpperTail = {uppertail}")
    print("-"*60)

    outliers = df[(df[col]<lowertail) | (df[col]>uppertail)]

    if len(outliers) == 0 :
        print("No Outliers")
    else:
        print(outliers)

    # handling of outliers
    df.loc[df[col]<lowertail, col] = lowertail
    df.loc[df[col]>uppertail, col] = uppertail

# %%
for i in ("temperature", "vibration_level", "power_consumption", "pressure", "material_flow_rate", "cycle_time", "error_rate", "downtime",
        "efficiency_score"):
    checking_and_handling_of_outliers(i)
# Out:
# Checking and Handling of Outliers for temperature
# ------------------------------------------------------------
# LowerTail = 67.8239768079857
# UpperTail = 87.54019322820338
# ------------------------------------------------------------
#                 timestamp machine_id machine_type  temperature  \
# 6     2025-03-10 08:06:00       M001       Welder    91.700813
# 43    2025-03-10 08:43:00       M004     Conveyor    66.266268
# 49    2025-03-10 08:49:00       M002       Welder    89.392208
# 59    2025-03-10 08:59:00       M001          CNC    88.304743
# 96    2025-03-10 09:36:00       M002       Welder    66.136665
# 107   2025-03-10 09:47:00       M004     Conveyor    90.418120
# 163   2025-03-10 10:43:00       M004       Welder    87.735532
# 190   2025-03-10 11:10:00       M003       Welder    67.699335
# 314   2025-03-10 13:14:00       M003       Welder    91.202490
# 513   2025-03-10 16:33:00       M002        Drill    90.466939
# 594   2025-03-10 17:54:00       M004        Drill    89.302073
# 604   2025-03-10 18:04:00       M003     Conveyor    93.359404
# 608   2025-03-10 18:08:00       M004       Welder    88.882155
# 631   2025-03-10 18:31:00       M004     Conveyor    90.271692
# 650   2025-03-10 18:50:00       M003          CNC    88.229621
# 680   2025-03-10 19:20:00       M004     Conveyor    89.140601
# 738   2025-03-10 20:18:00       M001          CNC    88.562516
# 752   2025-03-10 20:32:00       M002     Conveyor    88.724259
# 774   2025-03-10 20:54:00       M002     Conveyor    92.571148
# 775   2025-03-10 20:55:00       M001     Conveyor    89.395998
# 796   2025-03-10 21:16:00       M001     Conveyor    90.052565
# 967   2025-03-11 00:07:00       M002          CNC    88.744960
# 1159  2025-03-11 03:19:00       M004          CNC    90.493094
# 1163  2025-03-11 03:23:00       M002       Welder    91.351797
# 1168  2025-03-11 03:28:00       M003       Welder    91.201033
# 1222  2025-03-11 04:22:00       M001        Drill    91.523424
# 1392  2025-03-11 07:12:00       M004        Drill    90.847948
# 1461  2025-03-11 08:21:00       M001        Drill    90.682662
# 49           6.375078          23.967815  5.299018           20.631150
# ...               ...                ...       ...                 ...
# 2335         7.291334          27.186402  3.813299           19.364845
# 2430         6.201770          24.471954  4.509786           20.151144
# 2431         4.996859          27.516495  5.053921           19.718459
# 2448         5.505854          23.767258  5.038011           20.050935
# 2459         7.541178          23.514487  4.584506           19.649181
#
#       cycle_time  error_rate  downtime  maintenance_flag  efficiency_score  \
# 5     121.528506         1.0         0                 1               0.0
# 6     122.757183         1.0         0                 1               0.0
# 11    120.329242         1.0         0                 1               0.0
# 40    121.898050         1.0         0                 1               0.0
# 49    114.615915         1.0         0                 1               0.0
# ...          ...         ...       ...               ...               ...
# 2335  116.950486         1.0         0                 1               0.0
# 2430  112.444532         1.0         0                 1               0.0
# 2431  125.276765         1.0         0                 1               0.0
# 2448  115.682008         1.0         0                 1               0.0
# 2459  122.585002         1.0         0                 1               0.0
#
#       production_status
# 5                     0
# 6                     0
# 11                    0
# 40                    0
# 49                    0
# ...                 ...
# 2335                  0
# 2430                  0
# 2431                  0
# 2448                  0
# 2459                  0
#
# [123 rows x 14 columns]
# Checking and Handling of Outliers for power_consumption
# ------------------------------------------------------------
# LowerTail = 12.299065958012381
# UpperTail = 24.141046706004193
# ------------------------------------------------------------
#                 timestamp machine_id machine_type  temperature  \
# 6     2025-03-10 08:06:00       M001       Welder    87.540193
# 11    2025-03-10 08:11:00       M003     Conveyor    86.600674
# 43    2025-03-10 08:43:00       M004     Conveyor    67.823977
# 57    2025-03-10 08:57:00       M001     Conveyor    87.240166
# 59    2025-03-10 08:59:00       M001          CNC    87.540193
# ...                   ...        ...          ...          ...
# 2275  2025-03-11 21:55:00       M001        Drill    87.530268
# 2321  2025-03-11 22:41:00       M002     Conveyor    87.119156
# 2335  2025-03-11 22:55:00       M004     Conveyor    87.540193
# 2430  2025-03-12 00:30:00       M004     Conveyor    87.540193
# 2431  2025-03-12 00:31:00       M004     Conveyor    87.540193
#
#       vibration_level  power_consumption  pressure  material_flow_rate  \
# 6             2.87225          27.746653  4.948131           21.954393
# 11            2.87225          28.252621  4.560725           18.736556
# 43            1.33086          25.058110  5.191976           18.123158
# 57            2.87225          24.996155  4.399679           21.232882
# 59            2.87225          27.002462  5.534228           19.996631
# ...               ...                ...       ...                 ...
# 2275          2.87225          26.699522  5.185728           18.836776
# 2321          2.87225          26.149132  5.722744           19.157509
# 2335          2.87225          27.186402  3.813299           19.364845
# 2430          2.87225          24.471954  4.509786           20.151144
# 2431          2.87225          27.516495  5.053921           19.718459
#
#       cycle_time  error_rate  downtime  maintenance_flag  efficiency_score  \
# 6     122.757183    1.000000         0                 1          0.000000
# 11    120.329242    1.000000         0                 1          0.000000
# 43    124.739104    0.786454         0                 0         21.354575
# 57    109.923890    1.000000         0                 1          0.000000
# 59    121.309286    1.000000        50                 1          0.000000
# ...          ...         ...       ...               ...               ...
# 2275  115.295320    1.000000        50                 1          0.000000
# 2321  125.055485    1.000000         0                 1          0.000000
# 2335  116.950486    1.000000         0                 1          0.000000
# 2430  112.444532    1.000000         0                 1          0.000000
# 247   122.459072    0.544514         0                 0         45.548621
# 251   123.783212    0.540933         0                 0         45.906702
# 628   119.165802    0.547183        27                 0         31.781700
# 763   124.566955    0.576345         0                 0         42.365513
# 1199  119.920251    0.574262         0                 0         42.573847
# 1760  121.372570    0.573477         0                 0         42.652290
#
#       production_status
# 247                   0
# 251                   0
# 628                   0
# 763                   0
# 1199                  0
# 1760                  0
# Checking and Handling of Outliers for downtime
# ------------------------------------------------------------
# LowerTail = -54.0
# UpperTail = 90.0
# ------------------------------------------------------------
# No Outliers
# Checking and Handling of Outliers for efficiency_score
# ------------------------------------------------------------
# LowerTail = -21.64712257950271
# UpperTail = 51.353191196607014
# ------------------------------------------------------------
# No Outliers

# %% [markdown]
# ## Encoding

# %%
df
# Out:
#                 timestamp machine_id machine_type  temperature  \
# 0     2025-03-10 08:00:00       M003       Welder    78.302879
# 1     2025-03-10 08:01:00       M004     Conveyor    80.877076
# 2     2025-03-10 08:02:00       M001        Drill    71.315418
# 3     2025-03-10 08:03:00       M003     Conveyor    76.496198
# 4     2025-03-10 08:04:00       M003          CNC    73.612202
# ...                   ...        ...          ...          ...
# 2455  2025-03-12 00:55:00       M001     Conveyor    80.585617
# 2456  2025-03-12 00:56:00       M003        Drill    78.171483
# 2457  2025-03-12 00:57:00       M003       Welder    78.782847
# 2458  2025-03-12 00:58:00       M001        Drill    77.939129
# 2459  2025-03-12 00:59:00       M002          CNC    87.540193
#
#       vibration_level  power_consumption  pressure  material_flow_rate  \
# 0            2.043751          23.059855  5.088076           20.011026
# 1            2.175590          16.012814  5.412956           18.375739
# 2            2.154465          15.759164  5.769405           17.112107
# 3            2.245978          16.490268  4.618784           21.090684
# 4            2.097302          18.064286  5.431250           20.868592
# ...               ...                ...       ...                 ...
# 2455         1.744735          14.463169  5.034138           20.826884
# 2456         2.732367          19.990335  4.971981           18.291071
# 2457         2.131138          19.874735  5.290168           22.551457
# 2458         2.027617          19.660323  4.924919           22.706616
# 2459         2.872250          23.514487  4.584506           19.649181
#
#       cycle_time  error_rate  downtime  maintenance_flag  efficiency_score  \
# 0     118.146510    0.883246         0                 0         11.675410
# 1     123.062058    0.777073        38                 0          3.292706
# 2     122.754064    0.757374        37                 0          5.762582
# 3     118.990270    0.796481        39                 0          0.851911
# 4     113.749872    0.813361         0                 0         18.663902
# ...          ...         ...       ...               ...               ...
# 2455  113.009590    0.652834         0                 0         34.716573
# 2456  132.987186    0.988201         0                 0          1.179945
# 2457  114.350925    0.847650         0                 0         15.234984
# 2458  117.406875    0.807874         0                 0         19.212551
# 2459  122.585002    1.000000         0                 1          0.000000
#
#       production_status
# 0                     0
# 1                     0
# 2                     0
# 3                     0
# 4                     0
# ...                 ...
# 2455                  0
# 2456                  0
# 2457                  0
# 2458                  0
# 2459                  0
#
# [2303 rows x 14 columns]

# %%
df = df.drop(["timestamp", "production_status"], axis=1)

# %%
df
# Out:
#      machine_id machine_type  temperature  vibration_level  power_consumption  \
# 0          M003       Welder    78.302879         2.043751          23.059855
# 1          M004     Conveyor    80.877076         2.175590          16.012814
# 2          M001        Drill    71.315418         2.154465          15.759164
# 3          M003     Conveyor    76.496198         2.245978          16.490268
# 4          M003          CNC    73.612202         2.097302          18.064286
# ...         ...          ...          ...              ...                ...
# 2455       M001     Conveyor    80.585617         1.744735          14.463169
# 2456       M003        Drill    78.171483         2.732367          19.990335
# 2457       M003       Welder    78.782847         2.131138          19.874735
# 2458       M001        Drill    77.939129         2.027617          19.660323
# 2459       M002          CNC    87.540193         2.872250          23.514487
#
#       pressure  material_flow_rate  cycle_time  error_rate  downtime  \
# 0     5.088076           20.011026  118.146510    0.883246         0
# 1     5.412956           18.375739  123.062058    0.777073        38
# 2     5.769405           17.112107  122.754064    0.757374        37
# 3     4.618784           21.090684  118.990270    0.796481        39
# 4     5.431250           20.868592  113.749872    0.813361         0
# ...        ...                 ...         ...         ...       ...
# 2455  5.034138           20.826884  113.009590    0.652834         0
# 2456  4.971981           18.291071  132.987186    0.988201         0
# 2457  5.290168           22.551457  114.350925    0.847650         0
# 2458  4.924919           22.706616  117.406875    0.807874         0
# 2459  4.584506           19.649181  122.585002    1.000000         0
#
#       maintenance_flag  efficiency_score
# 0                    0         11.675410
# 1                    0          3.292706
# 2                    0          5.762582
# 3                    0          0.851911
# 4                    0         18.663902
# ...                ...               ...
# 2455                 0         34.716573
# 2456                 0          1.179945
# 2457                 0         15.234984
# 2458                 0         19.212551
# 2459                 1          0.000000
#
# [2303 rows x 12 columns]

# %%
le = LabelEncoder()
le_array = le.fit_transform(df["machine_id"])
df["machine_id"] = pd.DataFrame(le_array).values
df.head(10)
# Out:
#    machine_id machine_type  temperature  vibration_level  power_consumption  \
# 0           2       Welder    78.302879         2.043751          23.059855
# 1           3     Conveyor    80.877076         2.175590          16.012814
# 2           0        Drill    71.315418         2.154465          15.759164
# 3           2     Conveyor    76.496198         2.245978          16.490268
# 4           2          CNC    73.612202         2.097302          18.064286
# 5           3        Drill    86.820317         2.872250          20.040572
# 6           0       Welder    87.540193         2.872250          24.141047
# 7           0          CNC    70.505322         1.592745          21.387094
# 8           2          CNC    75.777486         1.729799          18.302815
# 9           1       Welder    76.421380         1.710740          17.414629
#
#    pressure  material_flow_rate  cycle_time  error_rate  downtime  \
# 0  5.088076           20.011026  118.146510    0.883246         0
# 1  5.412956           18.375739  123.062058    0.777073        38
# 2  5.769405           17.112107  122.754064    0.757374        37
# 3  4.618784           21.090684  118.990270    0.796481        39
# 4  5.431250           20.868592  113.749872    0.813361         0
# 5  4.965513           20.700636  121.528506    1.000000         0
# 6  4.948131           21.954393  122.757183    1.000000         0
# 7  4.385388           19.002452  123.629106    0.780886         0
# 8  4.886084           17.853329  121.746464    0.718756         0
# 9  4.601094           19.894955  118.644424    0.717481         0
#
#    maintenance_flag  efficiency_score
# 0                 0         11.675410
# 1                 0          3.292706
# 2                 0          5.762582
# 3                 0          0.851911
# 4                 0         18.663902
# 5                 1          0.000000
# 6                 1          0.000000
# 7                 0         21.911376
# 8                 0         28.124433
# 9                 0         28.251852

# %%
le = LabelEncoder()
le_array = le.fit_transform(df["machine_type"])
df["machine_type"] = pd.DataFrame(le_array).values
df
# Out:
#       machine_id  machine_type  temperature  vibration_level  \
# 0              2             3    78.302879         2.043751
# 1              3             1    80.877076         2.175590
# 2              0             2    71.315418         2.154465
# 3              2             1    76.496198         2.245978
# 4              2             0    73.612202         2.097302
# ...          ...           ...          ...              ...
# 2455           0             1    80.585617         1.744735
# 2456           2             2    78.171483         2.732367
# 2457           2             3    78.782847         2.131138
# 2458           0             2    77.939129         2.027617
# 2459           1             0    87.540193         2.872250
#
#       power_consumption  pressure  material_flow_rate  cycle_time  error_rate  \
# 0             23.059855  5.088076           20.011026  118.146510    0.883246
# 1             16.012814  5.412956           18.375739  123.062058    0.777073
# 2             15.759164  5.769405           17.112107  122.754064    0.757374
# 3             16.490268  4.618784           21.090684  118.990270    0.796481
# 4             18.064286  5.431250           20.868592  113.749872    0.813361
# ...                 ...       ...                 ...         ...         ...
# 2455          14.463169  5.034138           20.826884  113.009590    0.652834
# 2456          19.990335  4.971981           18.291071  132.987186    0.988201
# 2457          19.874735  5.290168           22.551457  114.350925    0.847650
# 2458          19.660323  4.924919           22.706616  117.406875    0.807874
# 2459          23.514487  4.584506           19.649181  122.585002    1.000000
#
#       downtime  maintenance_flag  efficiency_score
# 0            0                 0         11.675410
# 1           38                 0          3.292706
# 2           37                 0          5.762582
# 3           39                 0          0.851911
# 4            0                 0         18.663902
# ...        ...               ...               ...
# 2455         0                 0         34.716573
# 2456         0                 0          1.179945
# 2457         0                 0         15.234984
# 2458         0                 0         19.212551
# 2459         0                 1          0.000000
#
# [2303 rows x 12 columns]

# %%
df.isna().sum()
# Out:
# machine_id            0
# machine_type          0
# temperature           0
# vibration_level       0
# power_consumption     0
# pressure              0
# material_flow_rate    0
# cycle_time            0
# error_rate            0
# downtime              0
# maintenance_flag      0
# efficiency_score      0
# dtype: int64

# %% [markdown]
# ## Feature Extraction

# %%
x = df.drop(columns=["machine_id", "efficiency_score", "machine_type"], axis=1)
y = df["efficiency_score"]

# %%
x
# Out:
#       temperature  vibration_level  power_consumption  pressure  \
# 0       78.302879         2.043751          23.059855  5.088076
# 1       80.877076         2.175590          16.012814  5.412956
# 2       71.315418         2.154465          15.759164  5.769405
# 3       76.496198         2.245978          16.490268  4.618784
# 4       73.612202         2.097302          18.064286  5.431250
# ...           ...              ...                ...       ...
# 2455    80.585617         1.744735          14.463169  5.034138
# 2456    78.171483         2.732367          19.990335  4.971981
# 2457    78.782847         2.131138          19.874735  5.290168
# 2458    77.939129         2.027617          19.660323  4.924919
# 2459    87.540193         2.872250          23.514487  4.584506
#
#       material_flow_rate  cycle_time  error_rate  downtime  maintenance_flag
# 0              20.011026  118.146510    0.883246         0                 0
# 1              18.375739  123.062058    0.777073        38                 0
# 2              17.112107  122.754064    0.757374        37                 0
# 3              21.090684  118.990270    0.796481        39                 0
# 4              20.868592  113.749872    0.813361         0                 0
# ...                  ...         ...         ...       ...               ...
# 2455           20.826884  113.009590    0.652834         0                 0
# 2456           18.291071  132.987186    0.988201         0                 0
# 2457           22.551457  114.350925    0.847650         0                 0
# 2458           22.706616  117.406875    0.807874         0                 0
# 2459           19.649181  122.585002    1.000000         0                 1
#
# [2303 rows x 9 columns]

# %% [markdown]
# ## Scaling

# %%
b = StandardScaler()
c = b.fit_transform(x)
scale = pd.DataFrame(c, columns=x.columns, index=x.index)
print(scale)
# Out:
#       temperature  vibration_level  power_consumption  pressure  \
# 0        0.117886         0.029050           2.031993  0.240220
# 1        0.805950         0.407303          -0.987999  1.079545
# 2       -1.749811         0.346695          -1.096700  2.000430
# 3       -0.365027         0.609249          -0.783388 -0.972192
# 4       -1.135898         0.182691          -0.108846  1.126808
# ...           ...              ...                ...       ...
# 2455     0.728045        -0.828843          -1.652096  0.100871
# 2456     0.082765         2.004725           0.716558 -0.059709
# 2457     0.246178         0.279768           0.667017  0.762322
# 2458     0.020658        -0.017240           0.575132 -0.181293
# 2459     2.586952         2.406058           2.226824 -1.060748
#
#       material_flow_rate  cycle_time  error_rate  downtime  maintenance_flag
# 0              -0.008792   -0.378490    1.046414 -0.673286         -0.246580
# 1              -1.093712    0.598183   -0.207390  1.388075         -0.246580
# 2              -1.932061    0.536987   -0.440014  1.333829         -0.246580
# 3               0.707500   -0.210843    0.021800  1.442321         -0.246580
# 4               0.560155   -1.252060    0.221138 -0.673286         -0.246580
# ...                  ...         ...         ...       ...               ...
# 2455            0.532484   -1.399147   -1.674533 -0.673286         -0.246580
# 2456           -1.149885    2.570211    2.285830 -0.673286         -0.246580
# 2457            1.676641   -1.132636    0.626061 -0.673286         -0.246580
# 2458            1.779581   -0.525448    0.156348 -0.673286         -0.246580
# 2459           -0.248856    0.503396    2.425171 -0.673286          4.055486
#
# [2303 rows x 9 columns]

# %% [markdown]
# ## Train Test Split

# %%
trainx, testx, trainy, testy = train_test_split(x,y, test_size=0.2, random_state=42)

# %% [markdown]
# ## Multivariate Analysis

# %%
plt.figure(figsize=(10,8))
sns.heatmap(trainx.corr(), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Heatmap of feature")
plt.show()

# %%
sns.pairplot(trainx.corr())

# %% [markdown]
# ## Assumption 1 - Linearity

# %%
plt.figure(figsize=(10,8))
sns.heatmap(trainx.corr(), annot=True, cmap="viridis", fmt=".2f")
plt.title("Correlation Heatmap of feature")
plt.show()

# %% [markdown]
# ## Assumption 2 - Independance

# %%
x
# Out:
#       temperature  vibration_level  power_consumption  pressure  \
# 0       78.302879         2.043751          23.059855  5.088076
# 1       80.877076         2.175590          16.012814  5.412956
# 2       71.315418         2.154465          15.759164  5.769405
# 3       76.496198         2.245978          16.490268  4.618784
# 4       73.612202         2.097302          18.064286  5.431250
# ...           ...              ...                ...       ...
# 2455    80.585617         1.744735          14.463169  5.034138
# 2456    78.171483         2.732367          19.990335  4.971981
# 2457    78.782847         2.131138          19.874735  5.290168
# 2458    77.939129         2.027617          19.660323  4.924919
# 2459    87.540193         2.872250          23.514487  4.584506
#
#       material_flow_rate  cycle_time  error_rate  downtime  maintenance_flag
# 0              20.011026  118.146510    0.883246         0                 0
# 1              18.375739  123.062058    0.777073        38                 0
# 2              17.112107  122.754064    0.757374        37                 0
# 3              21.090684  118.990270    0.796481        39                 0
# 4              20.868592  113.749872    0.813361         0                 0
# ...                  ...         ...         ...       ...               ...
# 2455           20.826884  113.009590    0.652834         0                 0
# 2456           18.291071  132.987186    0.988201         0                 0
# 2457           22.551457  114.350925    0.847650         0                 0
# 2458           22.706616  117.406875    0.807874         0                 0
# 2459           19.649181  122.585002    1.000000         0                 1
#
# [2303 rows x 9 columns]

# %%
a = pd.DataFrame()
a["Independent Feature"] = x.columns
a
# Out:
#   Independent Feature
# 0         temperature
# 1     vibration_level
# 2   power_consumption
# 3            pressure
# 4  material_flow_rate
# 5          cycle_time
# 6          error_rate
# 7            downtime
# 8    maintenance_flag

# %%
a.shape[0]
# Out:
# 9

# %%
p = []

for i in range(a.shape[0]):
    vif = variance_inflation_factor(x.to_numpy(), i)
    p.append(vif)


a["VIF"] = p
a
# Out:
#   Independent Feature          VIF
# 0         temperature   386.714496
# 1     vibration_level   652.519447
# 2   power_consumption   534.168770
# 3            pressure   153.756740
# 4  material_flow_rate   156.594423
# 5          cycle_time   376.613259
# 6          error_rate  2433.885824
# 7            downtime     1.468027
# 8    maintenance_flag     2.339690

# %% [markdown]
# ## Model Training and Evaluation
# ### Algorithm 1 : Linear Regression

# %%
lin_reg = LinearRegression()
lin_reg
# Out:
# LinearRegression()

# %%
lin_reg_model = lin_reg.fit(trainx, trainy)
lin_reg_model
# Out:
# LinearRegression()

# %%
ytrain_pred = lin_reg_model.predict(trainx)
ytest_pred = lin_reg_model.predict(testx)

# %%
error = trainy - ytrain_pred
error
# Out:
# 1854    0.081940
# 378     1.774344
# 2318   -1.814359
# 369    -1.661124
# 1522    0.166862
#           ...
# 1749    0.292242
# 1167    1.030625
# 1205   -3.456465
# 1385    1.606395
# 907     0.352682
# Name: efficiency_score, Length: 1842, dtype: float64

# %% [markdown]
# ## Assumption 3 - Normality of residual

# %%
sns.kdeplot(error, fill = True, color = "red")
# Out:
# <Axes: xlabel='efficiency_score', ylabel='Density'>

# %%
sns.displot(error)

# %%
stats, pval = shapiro(error)

if pval > 0.05:
    print("Null Hypothesis(H0) is True")
    print("error is normally distributed")
else:
    print("Alternative Hypothesis(H1) is True")
    print("error is not normally distributed")
# Out:
# Alternative Hypothesis(H1) is True
# error is not normally distributed

# %% [markdown]
# ##  Assummption 4 - Homoscadasticity (after model training)

# %%
sns.scatterplot(x=trainy, y=error, color="red")
# Out:
# <Axes: xlabel='efficiency_score', ylabel='efficiency_score'>

# %%
# model evaluation for training data

print("Model Evaluation for Training Data")
print("-"* 50)
mse = mean_squared_error(trainy, ytrain_pred)
print(f"Mean Squared Error = {mse}")
print("-"* 50)

mae = mean_absolute_error(trainy, ytrain_pred)
print(f"Mean Absolute Error = {mae}")
print("-"* 50)

rmse = np.sqrt(mse)
print(f"Root Mean Squared Error = {rmse}")
print("-"* 50)

r2 = r2_score(trainy, ytrain_pred)
print(f"R2 Score = {r2}")
print("-"* 50)
# Out:
# Model Evaluation for Training Data
# --------------------------------------------------
# Mean Squared Error = 8.704320485035673
# --------------------------------------------------
# Mean Absolute Error = 1.9226345711724167
# --------------------------------------------------
# Root Mean Squared Error = 2.9503085406505662
# --------------------------------------------------
# R2 Score = 0.9233736166184194
# --------------------------------------------------

# %%
# model evaluation for training data

print("Model Evaluation for Training Data")
print("-"* 50)
mse = mean_squared_error(testy, ytest_pred)
print(f"Mean Squared Error = {mse}")
print("-"* 50)

mae = mean_absolute_error(testy, ytest_pred)
print(f"Mean Absolute Error = {mae}")
print("-"* 50)

rmse = np.sqrt(mse)
print(f"Root Mean Squared Error = {rmse}")
print("-"* 50)

r2 = r2_score(testy, ytest_pred)
print(f"R2 Score = {r2}")
print("-"* 50)
# Out:
# Model Evaluation for Training Data
# --------------------------------------------------
# Mean Squared Error = 10.709600943675362
# --------------------------------------------------
# Mean Absolute Error = 2.074703764356436
# --------------------------------------------------
# Root Mean Squared Error = 3.2725526647672702
# --------------------------------------------------
# R2 Score = 0.9142271633561194
# --------------------------------------------------

# %% [markdown]
# ### Lasso Regularization

# %%
lasso_model = Lasso(alpha=0.1)
lasso_model.fit(trainx, trainy)

ytrain_pred_lasso = lasso_model.predict(trainx)
ytest_pred_lasso = lasso_model.predict(testx)

# %%
# model evaluation for training data

print("Model Evaluation for Training Data")
print("-"* 50)
mse = mean_squared_error(trainy, ytrain_pred_lasso)
print(f"Mean Squared Error = {mse}")
print("-"* 50)

mae = mean_absolute_error(trainy, ytrain_pred_lasso)
print(f"Mean Absolute Error = {mae}")
print("-"* 50)

rmse = np.sqrt(mse)
print(f"Root Mean Squared Error = {rmse}")
print("-"* 50)

r2 = r2_score(trainy, ytrain_pred_lasso)
print(f"R2 Score = {r2}")
print("-"* 50)
# Out:
# Model Evaluation for Training Data
# --------------------------------------------------
# Mean Squared Error = 11.380863433816883
# --------------------------------------------------
# Mean Absolute Error = 2.4342225479172943
# --------------------------------------------------
# Root Mean Squared Error = 3.3735535320811025
# --------------------------------------------------
# R2 Score = 0.8998113171278194
# --------------------------------------------------

# %%
# model evaluation for training data

print("Model Evaluation for Training Data")
print("-"* 50)
mse = mean_squared_error(testy, ytest_pred_lasso)
print(f"Mean Squared Error = {mse}")
print("-"* 50)

mae = mean_absolute_error(testy, ytest_pred_lasso)
print(f"Mean Absolute Error = {mae}")
print("-"* 50)

rmse = np.sqrt(mse)
print(f"Root Mean Squared Error = {rmse}")
print("-"* 50)

r2 = r2_score(testy, ytest_pred_lasso)
print(f"R2 Score = {r2}")
print("-"* 50)
# Out:
# Model Evaluation for Training Data
# --------------------------------------------------
# Mean Squared Error = 14.814429172704248
# --------------------------------------------------
# Mean Absolute Error = 2.6443717069734975
# --------------------------------------------------
# Root Mean Squared Error = 3.84895169789181
# --------------------------------------------------
# R2 Score = 0.8813517310228905
# --------------------------------------------------

# %% [markdown]
# ## Model Training and Evaluation
# ### Algorithm 2: KNN Regression

# %%
knn = KNeighborsRegressor()
knn_model = knn.fit(trainx, trainy)
knn_model
# Out:
# KNeighborsRegressor()

# %%
ytrain_pred = knn_model.predict(trainx)
ytest_pred = knn_model.predict(testx)

# %%
# model evaluation for training data

print("Model Evaluation for Training Data")
print("-"* 50)
mse = mean_squared_error(trainy, ytrain_pred)
print(f"Mean Squared Error = {mse}")
print("-"* 50)

mae = mean_absolute_error(trainy, ytrain_pred)
print(f"Mean Absolute Error = {mae}")
print("-"* 50)

rmse = np.sqrt(mse)
print(f"Root Mean Squared Error = {rmse}")
print("-"* 50)

r2 = r2_score(trainy, ytrain_pred)
print(f"R2 Score = {r2}")
print("-"* 50)
# Out:
# Model Evaluation for Training Data
# --------------------------------------------------
# Mean Squared Error = 17.30794649779734
# --------------------------------------------------
# Mean Absolute Error = 2.90436189222341
# --------------------------------------------------
# Root Mean Squared Error = 4.1602820214256315
# --------------------------------------------------
# R2 Score = 0.8476336727067709
# --------------------------------------------------

# %%
# model evaluation for training data

print("Model Evaluation for Testing Data")
print("-"* 50)
mse = mean_squared_error(testy, ytest_pred)
print(f"Mean Squared Error = {mse}")
print("-"* 50)

mae = mean_absolute_error(testy, ytest_pred)
print(f"Mean Absolute Error = {mae}")
print("-"* 50)

rmse = np.sqrt(mse)
print(f"Root Mean Squared Error = {rmse}")
print("-"* 50)

r2 = r2_score(testy, ytest_pred)
print(f"R2 Score = {r2}")
print("-"* 50)
# Out:
# Model Evaluation for Testing Data
# --------------------------------------------------
# Mean Squared Error = 28.02464024459354
# --------------------------------------------------
# Mean Absolute Error = 3.615290198664324
# --------------------------------------------------
# Root Mean Squared Error = 5.2938303943924705
# --------------------------------------------------
# R2 Score = 0.7755515912922416
# --------------------------------------------------

# %% [markdown]
# ### KNN Hyperparameter Tuning

# %%
param_grid_ridge = {
    'alpha': [0.01, 0.1, 1, 10, 100]
}

ridge = Ridge()

# %%
grid_knn = GridSearchCV(estimator=ridge, param_grid=param_grid_ridge, cv=5, scoring="r2", n_jobs=-1)
grid_knn.fit(trainx, trainy)
# Out:
# GridSearchCV(cv=5, estimator=Ridge(), n_jobs=-1,
#              param_grid={'alpha': [0.01, 0.1, 1, 10, 100]}, scoring='r2')

# %%
ytrain_pred_grid_knn = grid_knn.predict(trainx)
ytest_pred_grid_knn = grid_knn.predict(testx)

# %%
# model evaluation for training data

print("Model Evaluation for Training Data")
print("-"* 50)
mse = mean_squared_error(trainy, ytrain_pred_grid_knn)
print(f"Mean Squared Error = {mse}")
print("-"* 50)

mae = mean_absolute_error(trainy, ytrain_pred_grid_knn)
print(f"Mean Absolute Error = {mae}")
print("-"* 50)

rmse = np.sqrt(mse)
print(f"Root Mean Squared Error = {rmse}")
print("-"* 50)

r2 = r2_score(trainy, ytrain_pred_grid_knn)
print(f"R2 Score = {r2}")
print("-"* 50)
# Out:
# Model Evaluation for Training Data
# --------------------------------------------------
# Mean Squared Error = 8.705208086482305
# --------------------------------------------------
# Mean Absolute Error = 1.925276225883932
# --------------------------------------------------
# Root Mean Squared Error = 2.9504589620061323
# --------------------------------------------------
# R2 Score = 0.9233658028334311
# --------------------------------------------------

# %%
# model evaluation for training data

print("Model Evaluation for Testing Data")
print("-"* 50)
mse = mean_squared_error(testy, ytest_pred_grid_knn)
print(f"Mean Squared Error = {mse}")
print("-"* 50)

mae = mean_absolute_error(testy, ytest_pred_grid_knn)
print(f"Mean Absolute Error = {mae}")
print("-"* 50)

rmse = np.sqrt(mse)
print(f"Root Mean Squared Error = {rmse}")
print("-"* 50)

r2 = r2_score(testy, ytest_pred_grid_knn)
print(f"R2 Score = {r2}")
print("-"* 50)
# Out:
# Model Evaluation for Testing Data
# --------------------------------------------------
# Mean Squared Error = 10.721897745568246
# --------------------------------------------------
# Mean Absolute Error = 2.078992069604515
# --------------------------------------------------
# Root Mean Squared Error = 3.2744309040760418
# --------------------------------------------------
# R2 Score = 0.9141286786800286
# --------------------------------------------------

# %% [markdown]
# ## Model Training and Evaluation
# ### Algorithm 3: Decission Tree

# %%
dt = DecisionTreeRegressor()
dt_model = dt.fit(trainx, trainy)
dt_model
# Out:
# DecisionTreeRegressor()

# %%
ytrain_pred = dt_model.predict(trainx)
ytest_pred = dt_model.predict(testx)

# %%
# model evaluation for training data

print("Model Evaluation for Training Data")
print("-"* 50)
mse = mean_squared_error(trainy, ytrain_pred)
print(f"Mean Squared Error = {mse}")
print("-"* 50)

mae = mean_absolute_error(trainy, ytrain_pred)
print(f"Mean Absolute Error = {mae}")
print("-"* 50)

rmse = np.sqrt(mse)
print(f"Root Mean Squared Error = {rmse}")
print("-"* 50)

r2 = r2_score(trainy, ytrain_pred)
print(f"R2 Score = {r2}")
print("-"* 50)
# Out:
# Model Evaluation for Training Data
# --------------------------------------------------
# Mean Squared Error = 0.0
# --------------------------------------------------
# Mean Absolute Error = 0.0
# --------------------------------------------------
# Root Mean Squared Error = 0.0
# --------------------------------------------------
# R2 Score = 1.0
# --------------------------------------------------

# %%
# model evaluation for training data

print("Model Evaluation for Testing Data")
print("-"* 50)
mse = mean_squared_error(testy, ytest_pred)
print(f"Mean Squared Error = {mse}")
print("-"* 50)

mae = mean_absolute_error(testy, ytest_pred)
print(f"Mean Absolute Error = {mae}")
print("-"* 50)

rmse = np.sqrt(mse)
print(f"Root Mean Squared Error = {rmse}")
print("-"* 50)

r2 = r2_score(testy, ytest_pred)
print(f"R2 Score = {r2}")
print("-"* 50)
# Out:
# Model Evaluation for Testing Data
# --------------------------------------------------
# Mean Squared Error = 0.028554799995460945
# --------------------------------------------------
# Mean Absolute Error = 0.046508448325440474
# --------------------------------------------------
# Root Mean Squared Error = 0.16898165579571336
# --------------------------------------------------
# R2 Score = 0.9997713055595358
# --------------------------------------------------

# %% [markdown]
# ## Model Training and Evaluation
# ### Algorithm 4: Random Forest

# %%
rm = RandomForestRegressor()
rm_model = rm.fit(trainx, trainy)
rm_model
# Out:
# RandomForestRegressor()

# %%
ytrain_pred = rm_model.predict(trainx)
ytest_pred = rm_model.predict(testx)

# %%
# model evaluation for training data

print("Model Evaluation for Training Data")
print("-"* 50)
mse = mean_squared_error(trainy, ytrain_pred)
print(f"Mean Squared Error = {mse}")
print("-"* 50)

mae = mean_absolute_error(trainy, ytrain_pred)
print(f"Mean Absolute Error = {mae}")
print("-"* 50)

rmse = np.sqrt(mse)
print(f"Root Mean Squared Error = {rmse}")
print("-"* 50)

r2 = r2_score(trainy, ytrain_pred)
print(f"R2 Score = {r2}")
print("-"* 50)
# Out:
# Model Evaluation for Training Data
# --------------------------------------------------
# Mean Squared Error = 0.0038889723852991247
# --------------------------------------------------
# Mean Absolute Error = 0.013284954804083675
# --------------------------------------------------
# Root Mean Squared Error = 0.062361625903267826
# --------------------------------------------------
# R2 Score = 0.9999657643707549
# --------------------------------------------------

# %%
# model evaluation for training data

print("Model Evaluation for Testing Data")
print("-"* 50)
mse = mean_squared_error(testy, ytest_pred)
print(f"Mean Squared Error = {mse}")
print("-"* 50)

mae = mean_absolute_error(testy, ytest_pred)
print(f"Mean Absolute Error = {mae}")
print("-"* 50)

rmse = np.sqrt(mse)
print(f"Root Mean Squared Error = {rmse}")
print("-"* 50)

r2 = r2_score(testy, ytest_pred)
print(f"R2 Score = {r2}")
print("-"* 50)
# Out:
# Model Evaluation for Testing Data
# --------------------------------------------------
# Mean Squared Error = 0.03284013981249117
# --------------------------------------------------
# Mean Absolute Error = 0.0324475619261283
# --------------------------------------------------
# Root Mean Squared Error = 0.1812184863983009
# --------------------------------------------------
# R2 Score = 0.9997369844159167
# --------------------------------------------------

# %% [markdown]
# ### Random Forest Hyperparameter Tuning

# %%
param_grid_rf = {
    'n_estimators': [100, 200, 300],
    'max_depth': [None, 10, 20],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'bootstrap': [True, False]
}

# %%
# rf = RandomForestRegressor()
# grid_rf = GridSearchCV(estimator=rf, param_grid=param_grid_rf, cv=5, scoring="r2", n_jobs=-1)
# grid_rf.fit(trainx, trainy)

# %% [markdown]
# ## Model Training and Evaluation
# ### Algorithm 5: Adaboost Regression

# %%
adb = AdaBoostRegressor()
adb_model = adb.fit(trainx, trainy)
adb_model
# Out:
# AdaBoostRegressor()

# %%
ytrain_pred = adb_model.predict(trainx)
ytest_pred = adb_model.predict(testx)

# %%
# model evaluation for training data

print("Model Evaluation for Training Data")
print("-"* 50)
mse = mean_squared_error(trainy, ytrain_pred)
print(f"Mean Squared Error = {mse}")
print("-"* 50)

mae = mean_absolute_error(trainy, ytrain_pred)
print(f"Mean Absolute Error = {mae}")
print("-"* 50)

rmse = np.sqrt(mse)
print(f"Root Mean Squared Error = {rmse}")
print("-"* 50)

r2 = r2_score(trainy, ytrain_pred)
print(f"R2 Score = {r2}")
print("-"* 50)
# Out:
# Model Evaluation for Training Data
# --------------------------------------------------
# Mean Squared Error = 1.0935749992844472
# --------------------------------------------------
# Mean Absolute Error = 0.8243300266870979
# --------------------------------------------------
# Root Mean Squared Error = 1.045741363475906
# --------------------------------------------------
# R2 Score = 0.9903729765814869
# --------------------------------------------------

# %%
# model evaluation for Testing data

print("Model Evaluation for Testing Data")
print("-"* 50)
mse = mean_squared_error(testy, ytest_pred)
print(f"Mean Squared Error = {mse}")
print("-"* 50)

mae = mean_absolute_error(testy, ytest_pred)
print(f"Mean Absolute Error = {mae}")
print("-"* 50)

rmse = np.sqrt(mse)
print(f"Root Mean Squared Error = {rmse}")
print("-"* 50)

r2 = r2_score(testy, ytest_pred)
print(f"R2 Score = {r2}")
print("-"* 50)
# Out:
# Model Evaluation for Testing Data
# --------------------------------------------------
# Mean Squared Error = 1.0952050745224848
# --------------------------------------------------
# Mean Absolute Error = 0.8226942581099219
# --------------------------------------------------
# Root Mean Squared Error = 1.0465204606325118
# --------------------------------------------------
# R2 Score = 0.991228539098458
# --------------------------------------------------

# %% [markdown]
# ## Model Training and Evaluation
# ### Algorithm 6: Gradiant boost Regression

# %%
gdb = GradientBoostingRegressor()
gdb_model = gdb.fit(trainx, trainy)
gdb_model
# Out:
# GradientBoostingRegressor()

# %%
ytrain_pred = gdb_model.predict(trainx)
ytest_pred = gdb_model.predict(testx)

# %%
# model evaluation for training data

print("Model Evaluation for Training Data")
print("-"* 50)
mse = mean_squared_error(trainy, ytrain_pred)
print(f"Mean Squared Error = {mse}")
print("-"* 50)

mae = mean_absolute_error(trainy, ytrain_pred)
print(f"Mean Absolute Error = {mae}")
print("-"* 50)

rmse = np.sqrt(mse)
print(f"Root Mean Squared Error = {rmse}")
print("-"* 50)

r2 = r2_score(trainy, ytrain_pred)
print(f"R2 Score = {r2}")
print("-"* 50)
# Out:
# Model Evaluation for Training Data
# --------------------------------------------------
# Mean Squared Error = 0.022311806855000463
# --------------------------------------------------
# Mean Absolute Error = 0.10175484483761824
# --------------------------------------------------
# Root Mean Squared Error = 0.14937137227394165
# --------------------------------------------------
# R2 Score = 0.9998035833964356
# --------------------------------------------------

# %%
# model evaluation for Testing data

print("Model Evaluation for Testing Data")
print("-"* 50)
mse = mean_squared_error(testy, ytest_pred)
print(f"Mean Squared Error = {mse}")
print("-"* 50)

mae = mean_absolute_error(testy, ytest_pred)
print(f"Mean Absolute Error = {mae}")
print("-"* 50)

rmse = np.sqrt(mse)
print(f"Root Mean Squared Error = {rmse}")
print("-"* 50)

r2 = r2_score(testy, ytest_pred)
print(f"R2 Score = {r2}")
print("-"* 50)
# Out:
# Model Evaluation for Testing Data
# --------------------------------------------------
# Mean Squared Error = 0.04506080427619498
# --------------------------------------------------
# Mean Absolute Error = 0.13116305931417735
# --------------------------------------------------
# Root Mean Squared Error = 0.2122753030293326
# --------------------------------------------------
# R2 Score = 0.999639109521956
# --------------------------------------------------

# %%
param_grid_gdb = {
    'learning_rate': [0.01, 0.1, 0.2],
    'n_estimators': [100, 200, 300],
    'max_depth': [3, 5, 7],
    'subsample': [0.8, 1.0],
    'max_features': ['sqrt', 'log2', None]
}

# %%
gdb = GradientBoostingRegressor(random_state=42)
grid_gdb = GridSearchCV(estimator=gdb, param_grid=param_grid_gdb, cv=2, scoring="r2", n_jobs=-1)
grid_gdb.fit(trainx, trainy)
# Out:
# GridSearchCV(cv=2, estimator=GradientBoostingRegressor(random_state=42),
#              n_jobs=-1,
#              param_grid={'learning_rate': [0.01, 0.1, 0.2],
#                          'max_depth': [3, 5, 7],
#                          'max_features': ['sqrt', 'log2', None],
#                          'n_estimators': [100, 200, 300],
#                          'subsample': [0.8, 1.0]},
#              scoring='r2')

# %%
ytrain_pred_grid_gdb = grid_gdb.predict(trainx)
ytest_pred_grid_gdb = grid_gdb.predict(testx)

# %%
# model evaluation for training data

print("Model Evaluation for Training Data")
print("-"* 50)
mse = mean_squared_error(trainy, ytrain_pred_grid_gdb)
print(f"Mean Squared Error = {mse}")
print("-"* 50)

mae = mean_absolute_error(trainy, ytrain_pred_grid_gdb)
print(f"Mean Absolute Error = {mae}")
print("-"* 50)

rmse = np.sqrt(mse)
print(f"Root Mean Squared Error = {rmse}")
print("-"* 50)

r2 = r2_score(trainy, ytrain_pred_grid_gdb)
print(f"R2 Score = {r2}")
print("-"* 50)
# Out:
# Model Evaluation for Training Data
# --------------------------------------------------
# Mean Squared Error = 7.435736638419616e-06
# --------------------------------------------------
# Mean Absolute Error = 0.0018854502288108655
# --------------------------------------------------
# Root Mean Squared Error = 0.00272685471531206
# --------------------------------------------------
# R2 Score = 0.9999999345412882
# --------------------------------------------------

# %%
# model evaluation for Testing data

print("Model Evaluation for Testing Data")
print("-"* 50)
mse = mean_squared_error(testy, ytest_pred_grid_gdb)
print(f"Mean Squared Error = {mse}")
print("-"* 50)

mae = mean_absolute_error(testy, ytest_pred_grid_gdb)
print(f"Mean Absolute Error = {mae}")
print("-"* 50)

rmse = np.sqrt(mse)
print(f"Root Mean Squared Error = {rmse}")
print("-"* 50)

r2 = r2_score(testy, ytest_pred_grid_gdb)
print(f"R2 Score = {r2}")
print("-"* 50)
# Out:
# Model Evaluation for Testing Data
# --------------------------------------------------
# Mean Squared Error = 0.01953367503490772
# --------------------------------------------------
# Mean Absolute Error = 0.028674632005218543
# --------------------------------------------------
# Root Mean Squared Error = 0.13976292439308688
# --------------------------------------------------
# R2 Score = 0.9998435554483649
# --------------------------------------------------

# %% [markdown]
# ## Model Training and Evaluation
# ### Algorithm 7: XGboost Regression

# %%
xgb = XGBRegressor()
xgb_model = xgb.fit(trainx, trainy)
xgb_model
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=None, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=None,
#              n_jobs=None, num_parallel_tree=None, ...)

# %%
ytrain_pred = xgb_model.predict(trainx)
ytest_pred = xgb_model.predict(testx)

# %%
# model evaluation for training data

print("Model Evaluation for Training Data")
print("-"* 50)
mse = mean_squared_error(trainy, ytrain_pred)
print(f"Mean Squared Error = {mse}")
print("-"* 50)

mae = mean_absolute_error(trainy, ytrain_pred)
print(f"Mean Absolute Error = {mae}")
print("-"* 50)

rmse = np.sqrt(mse)
print(f"Root Mean Squared Error = {rmse}")
print("-"* 50)

r2 = r2_score(trainy, ytrain_pred)
print(f"R2 Score = {r2}")
print("-"* 50)
# Out:
# Model Evaluation for Training Data
# --------------------------------------------------
# Mean Squared Error = 0.0002890422743364226
# --------------------------------------------------
# Mean Absolute Error = 0.012121262732603116
# --------------------------------------------------
# Root Mean Squared Error = 0.017001243317370133
# --------------------------------------------------
# R2 Score = 0.9999974554861387
# --------------------------------------------------

# %%
# model evaluation for Testing data

print("Model Evaluation for Testing Data")
print("-"* 50)
mse = mean_squared_error(testy, ytest_pred)
print(f"Mean Squared Error = {mse}")
print("-"* 50)

mae = mean_absolute_error(testy, ytest_pred)
print(f"Mean Absolute Error = {mae}")
print("-"* 50)

rmse = np.sqrt(mse)
print(f"Root Mean Squared Error = {rmse}")
print("-"* 50)

r2 = r2_score(testy, ytest_pred)
print(f"R2 Score = {r2}")
print("-"* 50)
# Out:
# Model Evaluation for Testing Data
# --------------------------------------------------
# Mean Squared Error = 0.09522116165285553
# --------------------------------------------------
# Mean Absolute Error = 0.10306342985660606
# --------------------------------------------------
# Root Mean Squared Error = 0.3085792631607891
# --------------------------------------------------
# R2 Score = 0.9992373768932712
# --------------------------------------------------

# %% [markdown]
# ### XGBoost Hyperparameter Tuning

# %%
param_grid_xgb = {
    'n_estimators': [100, 200, 300],
    'learning_rate': [0.01, 0.1, 0.2],
    'max_depth': [3, 5, 7],
    'subsample': [0.8, 1.0],
    'colsample_bytree': [0.8, 1.0]
}

# %%
xgb = XGBRegressor(random_state=42)
grid_xgb = GridSearchCV(estimator=xgb, param_grid=param_grid_xgb, cv=2, scoring="r2", n_jobs=-1)
grid_xgb.fit(trainx, trainy)
# Out:
# GridSearchCV(cv=2,
#              estimator=XGBRegressor(base_score=None, booster=None,
#                                     callbacks=None, colsample_bylevel=None,
#                                     colsample_bynode=None,
#                                     colsample_bytree=None, device=None,
#                                     early_stopping_rounds=None,
#                                     enable_categorical=False, eval_metric=None,
#                                     feature_types=None, feature_weights=None,
#                                     gamma=None, grow_policy=None,
#                                     importance_type=None,
#                                     interaction_constraints=None...
#                                     max_cat_to_onehot=None, max_delta_step=None,
#                                     max_depth=None, max_leaves=None,
#                                     min_child_weight=None, missing=nan,
#                                     monotone_constraints=None,
#                                     multi_strategy=None, n_estimators=None,
#                                     n_jobs=None, num_parallel_tree=None, ...),
#              n_jobs=-1,
#              param_grid={'colsample_bytree': [0.8, 1.0],
#                          'learning_rate': [0.01, 0.1, 0.2],
#                          'max_depth': [3, 5, 7],
#                          'n_estimators': [100, 200, 300],
#                          'subsample': [0.8, 1.0]},
#              scoring='r2')

# %%
ytrain_pred_grid_xgb = grid_xgb.predict(trainx)
ytest_pred_grid_xgb = grid_xgb.predict(testx)

# %%
# model evaluation for training data

print("Model Evaluation for Training Data")
print("-"* 50)
mse = mean_squared_error(trainy, ytrain_pred_grid_xgb)
print(f"Mean Squared Error = {mse}")
print("-"* 50)

mae = mean_absolute_error(trainy, ytrain_pred_grid_xgb)
print(f"Mean Absolute Error = {mae}")
print("-"* 50)

rmse = np.sqrt(mse)
print(f"Root Mean Squared Error = {rmse}")
print("-"* 50)

r2 = r2_score(trainy, ytrain_pred_grid_xgb)
print(f"R2 Score = {r2}")
print("-"* 50)
# Out:
# Model Evaluation for Training Data
# --------------------------------------------------
# Mean Squared Error = 0.003471850572552715
# --------------------------------------------------
# Mean Absolute Error = 0.03837335348654009
# --------------------------------------------------
# Root Mean Squared Error = 0.05892241146247084
# --------------------------------------------------
# R2 Score = 0.9999694364019025
# --------------------------------------------------

# %%
# model evaluation for Testing data

print("Model Evaluation for Testing Data")
print("-"* 50)
mse = mean_squared_error(testy, ytest_pred_grid_xgb)
print(f"Mean Squared Error = {mse}")
print("-"* 50)

mae = mean_absolute_error(testy, ytest_pred_grid_xgb)
print(f"Mean Absolute Error = {mae}")
print("-"* 50)

rmse = np.sqrt(mse)
print(f"Root Mean Squared Error = {rmse}")
print("-"* 50)

r2 = r2_score(testy, ytest_pred_grid_xgb)
print(f"R2 Score = {r2}")
print("-"* 50)
# Out:
# Model Evaluation for Testing Data
# --------------------------------------------------
# Mean Squared Error = 0.0914672684587555
# --------------------------------------------------
# Mean Absolute Error = 0.08776271560018267
# --------------------------------------------------
# Root Mean Squared Error = 0.30243556083694173
# --------------------------------------------------
# R2 Score = 0.9992674416986183
# --------------------------------------------------

# %% [markdown]
# ## Model Training and Evaluation
# ### Algorithm 8: Support Vector Machine (SVM)

# %%
svm = SVR()
svm_model = svm.fit(trainx, trainy)
svm_model
# Out:
# SVR()

# %%
ytrain_pred = svm_model.predict(trainx)
ytest_pred = svm_model.predict(testx)

# %%
# model evaluation for training data

print("Model Evaluation for Training Data")
print("-"* 50)
mse = mean_squared_error(trainy, ytrain_pred)
print(f"Mean Squared Error = {mse}")
print("-"* 50)

mae = mean_absolute_error(trainy, ytrain_pred)
print(f"Mean Absolute Error = {mae}")
print("-"* 50)

rmse = np.sqrt(mse)
print(f"Root Mean Squared Error = {rmse}")
print("-"* 50)

r2 = r2_score(trainy, ytrain_pred)
print(f"R2 Score = {r2}")
print("-"* 50)
# Out:
# Model Evaluation for Training Data
# --------------------------------------------------
# Mean Squared Error = 50.25329416517668
# --------------------------------------------------
# Mean Absolute Error = 5.296913356702509
# --------------------------------------------------
# Root Mean Squared Error = 7.088955788067569
# --------------------------------------------------
# R2 Score = 0.5576072604968665
# --------------------------------------------------

# %%
# model evaluation for Testing data

print("Model Evaluation for Testing Data")
print("-"* 50)
mse = mean_squared_error(testy, ytest_pred)
print(f"Mean Squared Error = {mse}")
print("-"* 50)

mae = mean_absolute_error(testy, ytest_pred)
print(f"Mean Absolute Error = {mae}")
print("-"* 50)

rmse = np.sqrt(mse)
print(f"Root Mean Squared Error = {rmse}")
print("-"* 50)

r2 = r2_score(testy, ytest_pred)
print(f"R2 Score = {r2}")
print("-"* 50)
# Out:
# Model Evaluation for Testing Data
# --------------------------------------------------
# Mean Squared Error = 54.42090396054588
# --------------------------------------------------
# Mean Absolute Error = 5.553725819738757
# --------------------------------------------------
# Root Mean Squared Error = 7.3770525252668415
# --------------------------------------------------
# R2 Score = 0.564144795873385
# --------------------------------------------------

# %% [markdown]
# ### SVM Hyperparameter Tuning

# %%
param_grid_svr = {'kernel': ['linear', 'rbf', 'poly'], 
                   'C': [0.01, 0.1, 1, 10, 100], 
                   'gamma': ['scale', 'auto'], 
                   'epsilon': [0.01, 0.1, 0.2]}

# %%
# svr = SVR()
# grid_svr = GridSearchCV(estimator=svr, param_grid=param_grid_svr, cv=2, scoring="r2", n_jobs=-1)
# grid_svr.fit(trainx, trainy)

# %%
filename = "Production_System_ML_Model(R).pkl"

with open(filename, "wb") as file:
    pickle.dump(rm_model, file)

print(f"Best Fit Model Saved to {filename}")
# Out:
# Best Fit Model Saved to Production_System_ML_Model(R).pkl

# %%
with open(filename, "rb") as file:
    FinalModel = pickle.load(file)

FinalModel
# Out:
# RandomForestRegressor()
